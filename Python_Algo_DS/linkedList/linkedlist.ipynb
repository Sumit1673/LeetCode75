# %% [markdown]
# ### Create a LinkedList

# %%
class Node:
    def __init__(self, value=None) -> None:
        self.val = value
        self.next = None
    
    def __repr__(self) -> str:
        return f"Node({self.val})"    
    
        
class LinkedList:
    def __init__(self, val) -> None:
        self.head = Node(val)
        
    def __str__(self) -> str:
        current = self.head
        elements = [str(current.val)]
        while current.next:
            elements.append(str(current.next.val))
            current = current.next
        return " -> ".join(elements)
    
    def add_node(self, val, current=None):
        if current is None:
            current = self.head
        if current.next is None:
            current.next = Node(val)
            
        else:
            self.add_node(val, current.next)
            
    def delete_node(self, val, prev=None, current=None):
        
        if current is None:
            current = self.head
        
        if current.val == val and prev is None:
            self.head = current.next
            return
        if current.val == val:
            prev.next = current.next
            return
        self.delete_node(val, current, current.next)
        
    def reverse(self):
        prev = None
        current = self.head
        while current:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
        self.head = prev
        
    def delete_middle_node(self):
        # use floor to find the mid n =5 mid=5//2 = 2
        if not self.head or not self.head.next:
            return None  # There's no middle node in a list with 0 or 1 elements
        
        slow = self.head
        fast = self.head
        prev_slow = None
        
        while fast and fast.next:
            fast = fast.next.next
            prev_slow = slow
            slow = slow.next
        
        prev_slow.next = slow.next  # Remove the middle node
        
        return self.head
    
    def odd_even_elements(self):
        # odd is 0th index and even is 1st index
        # output is [odd_elements + even_elements]
        if not self.head or not self.head.next:
            return None 
        # if not head or not head.next:
        #     return head
        
        odd_head = odd = self.head
        even_head = even =self.head.next
        
        while even and even.next:
            odd.next = even.next
            odd = odd.next
            even.next = odd.next
            even = even.next
        
        odd.next = even_head  # Connect odd list to even list
        
        return odd_head
        # odd = self.head
        # even = self.head.next
        
        # while odd and even:
        #     temp = odd.next
        #     odd.next = even.next
        #     even.next = temp
        # return self.head
        
        
 
            
                
        
    
l=LinkedList(10)
l.add_node(20)
l.add_node(21)
l.add_node(5)
l.add_node(1)
l.add_node(120)
l.add_node(211)
# l.odd_even_elements()


print(l)
# Out:
# 10 -> 20 -> 21 -> 5 -> 1 -> 120 -> 211

# %% [markdown]
# ```python
# 2095. Delete the Middle Node of a Linked List
#
# You are given the head of a linked list. Delete the middle node, and return the head of the modified linked list.
#
# The middle node of a linked list of size n is the ⌊n / 2⌋th node from the start using 0-based indexing, where ⌊x⌋ denotes the largest integer less than or equal to x.
#
# For n = 1, 2, 3, 4, and 5, the middle nodes are 0, 1, 1, 2, and 2, respectively.
#
#
# Example 1:
#
#
# Input: head = [1,3,4,7,1,2,6]
# Output: [1,3,4,1,2,6]
# Explanation:
# The above figure represents the given linked list. The indices of the nodes are written below.
# Since n = 7, node 3 with value 7 is the middle node, which is marked in red.
# We return the new list after removing this node.
# Example 2:
#
#
# Input: head = [1,2,3,4]
# Output: [1,2,4]
# Explanation:
# The above figure represents the given linked list.
# For n = 4, node 2 with value 3 is the middle node, which is marked in red.
# Example 3:
#
#
# Input: head = [2,1]
# Output: [2]
# Explanation:
# The above figure represents the given linked list.
# For n = 2, node 1 with value 1 is the middle node, which is marked in red.
# Node 0 with value 2 is the only node remaining after removing node 1.
#
#
# Constraints:
#
# The number of nodes in the list is in the range [1, 105].
# 1 <= Node.val <= 105```

# %%
list(range(0,3))
# Out:
# [0, 1, 2]

# %%
class Solution:
    def __init__(self, val) -> None:
        self.head = Node(val)
        
    def __str__(self) -> str:
        current = self.head
        elements = [str(current.val)]
        while current.next:
            elements.append(str(current.next.val))
            current = current.next
        return " -> ".join(elements)
    
    def add_node(self, val, current=None):
        if current is None:
            current = self.head
        if current.next is None:
            current.next = Node(val)
            
        else:
            self.add_node(val, current.next)
            
    def deleteMiddle(self):
        
        len = 0
        leng_of_ll = self.find_length(self.head, len)

        mid_node = leng_of_ll // 2
        print(mid_node)
        return self.delete_recursive(self.head, mid_node)


    @staticmethod
    def delete_recursive(node, mid_idx):
        curr = node
        for i in range(0, mid_idx-1):
            curr = curr.next
        
        curr.next = curr.next.next
        return node
    
    def find_length(self, node, len):
    
        if node is None:
            return len
    
        curr = node.next
        return self.find_length(curr, len+1)


l=Solution(10)
l.add_node(20)
l.add_node(21)
l.add_node(5)
l.add_node(1)
l.add_node(120)
l.add_node(211)  
print(l)
l.deleteMiddle()
print(l)
# Out:
# 10 -> 20 -> 21 -> 5 -> 1 -> 120 -> 211
# 3
# 10 -> 20 -> 21 -> 1 -> 120 -> 211
